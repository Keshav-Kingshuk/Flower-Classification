# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the Dataset

# %%
iris = pd.read_csv("/kaggle/input/iris-flower-dataset/IRIS.csv")
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#Checking for Null Values
iris.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
np.dtype(iris)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 np.dtype(iris)
#
# TypeError: Cannot interpret '     sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# ...

# %%
iris.shape

# %%
iris.size

# %%
print("Mean Sepal Length is: ",iris.sepal_length.mean())

# %%
print("Mean Sepal Width is: ",iris.sepal_width.mean())

# %%
print("Mean Petal Length is: ",iris.petal_length.mean())

# %%
print("Mean Petal Width is: ",iris.petal_width.mean())
# Out:
# Mean Petal Width is:  1.1986666666666668

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.sepal_length.plot(kind = 'line', legend = True, marker = "p", color = "r", grid = True)
iris.sepal_width.plot(kind = 'line', legend = True, marker = "o", color = "b", grid = True)
plt.title('Sepal Length & Width')
plt.xlabel('Count',color = 'blue')
plt.ylabel('Length/Width',color = 'blue')
# Out:
# Text(0, 0.5, 'Length/Width')

# %% [markdown]
# Conclusion: Sepal Length > Sepal Width

# %%
iris.petal_length.plot(kind = 'line', legend = True, marker = "p", color = "r", grid = True)
iris.petal_width.plot(kind = 'line', legend = True, marker = "o", color = "b", grid = True)
plt.title('Petal Length & Width')
plt.xlabel('Count',color = 'blue')
plt.ylabel('Length/Width',color = 'blue')
# Out:
# Text(0, 0.5, 'Length/Width')

# %% [markdown]
# Conclusion: Petal Length > Petal Width

# %%
iris.petal_length.plot(kind = 'line', legend = True, marker = "p", color = "r", grid = True)
iris.petal_width.plot(kind = 'line', legend = True, marker = "o", color = "b", grid = True)
iris.sepal_length.plot(kind = 'line', legend = True, marker = "d", color = "g", grid = True)
iris.sepal_width.plot(kind = 'line', legend = True, marker = "*", color = "y", grid = True)
plt.title('Length & Width')
plt.xlabel('Count',color = 'blue')
plt.ylabel('Length/Width',color = 'blue')
plt.xticks(rotation = 45)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120., 140., 160.]),
#  [Text(-20.0, 0, '−20'),
#   Text(0.0, 0, '0'),
#   Text(20.0, 0, '20'),
#   Text(40.0, 0, '40'),
#   Text(60.0, 0, '60'),
#   Text(80.0, 0, '80'),
#   Text(100.0, 0, '100'),
#   Text(120.0, 0, '120'),
#   Text(140.0, 0, '140'),
#   Text(160.0, 0, '160')])

# %% [markdown]
# # Training the Model - Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#X_train, X_test, y_train, y_test = train_test_split((iris.petal_length,iris.petal_width,iris.sepal_length,iris.sepal_width),iris.species,test_size=0.2)

# %%
X_train,X_test,y_train,y_test = train_test_split(iris.iloc[:,:4],iris['species'],test_size=0.2)

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # Training the Model - SVM (Support Vector Machine)

# %%
X = iris.drop(['species'],axis = 1)
y = iris.species

# %%
from sklearn.svm import SVC
model_SVC = SVC()

# %%
model_SVC.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# # Prediction and Score - Using LR + SVM

# %%
model.predict(X_test)
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor'],
#       dtype=object)

# %%
model.predict_log_proba(X_test)
# Out:
# array([[-4.97316212e+00, -2.30282917e-01, -1.61560728e+00],
#        [-6.53583533e+00, -8.02109637e-01, -5.97532610e-01],
#        [-6.14701301e+00, -8.32662373e-01, -5.74528527e-01],
#        [-2.09794262e-02, -3.87468544e+00, -1.76557193e+01],
#        [-3.87291104e-02, -3.27046951e+00, -1.57779230e+01],
#        [-1.83454790e-02, -4.00753362e+00, -1.67972887e+01],
#        [-7.11144488e+00, -7.92151046e-01, -6.04560130e-01],
#        [-2.98125936e-02, -3.52769537e+00, -1.67911538e+01],
#        [-3.88802379e+00, -5.46886949e-02, -3.41932968e+00],
#        [-3.97526323e-02, -3.24489494e+00, -1.54017291e+01],
#        [-1.07452337e+01, -3.22049422e+00, -4.07770624e-02],
#        [-4.75525547e-02, -3.06960543e+00, -1.56038373e+01],
#        [-6.32417429e-02, -2.79224827e+00, -1.54040587e+01],
#        [-2.51644477e+00, -9.82745269e-02, -4.35411630e+00],
#        [-3.79520019e+00, -7.72898461e-02, -2.95843519e+00],
#        [-4.52701163e+00, -8.26148971e-02, -2.68119290e+00],
# ...

# %%
model.predict_proba(X_test)
# Out:
# array([[6.92122766e-03, 7.94308847e-01, 1.98769925e-01],
#        [1.45051686e-03, 4.48382043e-01, 5.50167441e-01],
#        [2.13986399e-03, 4.34889905e-01, 5.62970231e-01],
#        [9.79239111e-01, 2.07608675e-02, 2.14891159e-08],
#        [9.62011273e-01, 3.79885868e-02, 1.40519023e-07],
#        [9.81821775e-01, 1.81781743e-02, 5.07025987e-08],
#        [8.15715529e-04, 4.52869603e-01, 5.46314681e-01],
#        [9.70627418e-01, 2.93725307e-02, 5.10146102e-08],
#        [2.04857904e-02, 9.46779840e-01, 3.27343701e-02],
#        [9.61027137e-01, 3.89726584e-02, 2.04698218e-07],
#        [2.15478685e-05, 3.99353164e-02, 9.60043136e-01],
#        [9.53560358e-01, 4.64394750e-02, 1.67239773e-07],
#        [9.38716518e-01, 6.12832776e-02, 2.04221896e-07],
#        [8.07461681e-02, 9.06400038e-01, 1.28537935e-02],
#        [2.24784054e-02, 9.25621527e-01, 5.19000676e-02],
#        [1.08129409e-02, 9.20705645e-01, 6.84814137e-02],
# ...

# %%
model.score(X_test,y_test)
# Out:
# 0.9666666666666667

# %%
model_SVC.score(X_test,y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# Thank you!
